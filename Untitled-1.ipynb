# %%
while True:
    choice = input("Roll the dice? (y/n): ").capitalize()
    if choice == "y":
        dice1 = random.randint(1, 6) # type: ignore
        dice2 = random.randint(1, 6)
        print(f'({dice1}, {dice2})')
    elif  choice == "n":
        print("Thanks for Trying😊")
        break
# Out:
# Traceback (most recent call last):
#   File "c:\Users\user\.vscode\extensions\ms-python.python-2025.0.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in <module>
# AttributeError: 'NoneType' object has no attribute 'capitalize'

# %%
Temp = int(input("Whats your body Temperature? "))
# Out:
# Traceback (most recent call last):
#   File "c:\Users\user\.vscode\extensions\ms-python.python-2025.0.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# ValueError: invalid literal for int() with base 10: ''

# %%
print("Thanks Bye")
# Out:
# Thanks Bye

# %%
print("Thanks Bye")
# Out:
# Thanks Bye

# %%
deprecated
# Out:
# Traceback (most recent call last):
#   File "c:\Users\user\.vscode\extensions\ms-python.python-2025.0.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# NameError: name 'deprecated' is not defined

# %%
while True:
 user_choice =  input("Rock, Paper, Scissor? (or type quit to exit) ").lower()
 if user_choice == "quit":
    print("Bye")
 if user_choice not in options:
    print("Invalid choice")
    continue
 computer_choice = random.choice(options)
 print(f"You chose: {user_choice}")
 print(f"Computer chose: {computer_choice}")
 if user_choice == computer_choice:
    print("Its a tie!")
 elif(user_choice == "rock" and computer_choice == "scissor") or \
    (user_choice == "paper" and computer_choice == "rock") or \
    (user_choice == "scissor" and computer_choice == "paper"):
    print("You win!")
 else:
    print("You lose!")
 play_again = input("Wanna play again? (y/n): ").lower()
 if play_again == "n":
    print("Thanks Bye")
    break
# Out:
# Traceback (most recent call last):
#   File "c:\Users\user\.vscode\extensions\ms-python.python-2025.0.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in <module>
# AttributeError: 'NoneType' object has no attribute 'lower'

# %%
while True:
 user_choice =  input("Rock, Paper, Scissor? (or type quit to exit) ").lower()
 if user_choice == "quit":
    print("Bye / ")
 if user_choice not in options:
    print("Invalid choice")
    continue
 computer_choice = random.choice(options)
 print(f"You chose: {user_choice}")
 print(f"Computer chose: {computer_choice}")
 if user_choice == computer_choice:
    print("Its a tie!")
 elif(user_choice == "rock" and computer_choice == "scissor") or \
    (user_choice == "paper" and computer_choice == "rock") or \
    (user_choice == "scissor" and computer_choice == "paper"):
    print("You win!")
 else:
    print("You lose!")
 play_again = input("Wanna play again? (y/n): ").lower()
 if play_again == "n":
    print("Thanks Bye")
    break

# %%
while True:
 user_choice =  input("Rock, Paper, Scissor? (or type quit to exit) ").lower()
 if user_choice == "quit":
    print("Bye")
 if user_choice not in options:
    print("Invalid choice")
    continue
 computer_choice = random.choice(options)
 print(f"You chose: {user_choice}")
 print(f"Computer chose: {computer_choice}")
 if user_choice == computer_choice:
    print("Its a tie!")
 elif(user_choice == "rock" and computer_choice == "scissor") or \
    (user_choice == "paper" and computer_choice == "rock") or \
    (user_choice == "scissor" and computer_choice == "paper"):
    print("You win!")
 else:
    print("You lose!")
 play_again = input("Wanna play again? (y/n): ").lower()
 if play_again == "n":
    print("Thanks Bye")
    break
# Out:
# Traceback (most recent call last):
#   File "c:\Users\user\.vscode\extensions\ms-python.python-2025.0.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 2, in <module>
# AttributeError: 'NoneType' object has no attribute 'lower'

# %%
print("hello, dean")
# Out:
# hello, dean

# %%
print("hello, dean")
# Out:
# hello, dean

# %%
PS C:\Users\user\OneDrive\Documents\Mary school\Python> python index.py
# Out:
# Traceback (most recent call last):
#   File "c:\Users\user\.vscode\extensions\ms-python.python-2025.0.0-win32-x64\python_files\python_server.py", line 133, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1
#     PS C:\Users\user\OneDrive\Documents\Mary school\Python> python index.py
#        ^
# SyntaxError: invalid syntax
